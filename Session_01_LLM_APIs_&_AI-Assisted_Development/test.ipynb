# %%
# %%
# Out:
# Running cells with 'activate (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/roberra/Documents/ai_eng/code/AIEO1-Rob/Session_01_LLM_APIs_&_AI-Assisted_Development/activate/bin/python -m pip install ipykernel -U --force-reinstall'
